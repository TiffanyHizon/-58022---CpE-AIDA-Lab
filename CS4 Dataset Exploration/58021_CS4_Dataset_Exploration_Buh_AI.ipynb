# %% [markdown]
# <a href="https://colab.research.google.com/github/TiffanyHizon/-58022---CpE-AIDA-Lab/blob/main/CS4%20Dataset%20Exploration/58021_CS4_Dataset_Exploration_Buh_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **CpE Elective 1 AIDA - Fundamentals of AI & Data Analytic**
#
# **Buh-AI**
#
#
#
# *   Hizon, Tiffany Joyce C.
# *   Imbat, Jezra Mayne A.
#
# *   Ebdane, Precious Anne G.
# *   Joaquin, Marc Christopher C.

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# # Importing Files

# %% [markdown]
# ## Gender Development Index (GDI)

# %% [markdown]
# ### Gender Development

# %%
genderDev_origDF = pd.read_csv('/content/gender_development.csv')
genderDev_origDF
# Out:
#      GDI Rank                          Country Gender Development Index (GDI)  \
# 0         1.0                           Norway                          0.996
# 1         2.0                        Australia                          0.976
# 2         3.0                      Switzerland                           0.95
# 3         4.0                          Denmark                          0.977
# 4         5.0                      Netherlands                          0.947
# ..        ...                              ...                            ...
# 190       NaN          Europe and Central Asia                          0.945
# 191       NaN  Latin America and the Caribbean                          0.976
# 192       NaN                       South Asia                          0.801
# 193       NaN               Sub-Saharan Africa                          0.872
# 194       NaN                            World                          0.924
#
# ...

# %%
genderDev_DF = genderDev_origDF.copy()
genderDev_DF.head(10)
# Out:
#    GDI Rank        Country Gender Development Index (GDI)  \
# 0       1.0         Norway                          0.996
# 1       2.0      Australia                          0.976
# 2       3.0    Switzerland                           0.95
# 3       4.0        Denmark                          0.977
# 4       5.0    Netherlands                          0.947
# 5       6.0        Germany                          0.963
# 6       6.0        Ireland                          0.973
# 7       8.0  United States                          0.995
# 8       9.0         Canada                          0.982
# 9       9.0    New Zealand                          0.961
#
#   Human Development Index (Female) Human Development Index (Male)  \
# 0                             0.94                          0.944
# 1                            0.922                          0.945
# 2                            0.898                          0.945
# ...

# %%
genderDev_DF.columns = ['Rank', 'Country', 'GDI', 'F_HDI', 'M_HDI', 'F_Life Expectancy', 
                    'M_Life Expectancy', 'F_Exp Education Years', 'M_Exp Education Years',
                    'F_Mean Educ Years', 'M_Mean Educ Years', 'F_Est GNI', 'M_Est GNI']
genderDev_DF.columns
# Out:
# Index(['Rank', 'Country', 'GDI', 'F_HDI', 'M_HDI', 'F_Life Expectancy',
#        'M_Life Expectancy', 'F_Exp Education Years', 'M_Exp Education Years',
#        'F_Mean Educ Years', 'M_Mean Educ Years', 'F_Est GNI', 'M_Est GNI'],
#       dtype='object')

# %%
genderDev_DF.isnull().sum()
# Out:
# Rank                     7
# Country                  0
# GDI                      0
# F_HDI                    0
# M_HDI                    0
# F_Life Expectancy        0
# M_Life Expectancy        0
# F_Exp Education Years    0
# M_Exp Education Years    0
# F_Mean Educ Years        0
# M_Mean Educ Years        0
# F_Est GNI                0
# M_Est GNI                0
# dtype: int64

# %%
genderDev_DF = genderDev_DF.replace('..', '0')
genderDev_DF.head(10)
# Out:
#    Rank        Country    GDI  F_HDI  M_HDI F_Life Expectancy  \
# 0   1.0         Norway  0.996   0.94  0.944              83.6
# 1   2.0      Australia  0.976  0.922  0.945              84.5
# 2   3.0    Switzerland   0.95  0.898  0.945                85
# 3   4.0        Denmark  0.977  0.912  0.934              82.2
# 4   5.0    Netherlands  0.947  0.893  0.943              83.3
# 5   6.0        Germany  0.963  0.901  0.936              83.3
# 6   6.0        Ireland  0.973  0.901  0.926                83
# 7   8.0  United States  0.995  0.911  0.916              81.4
# 8   9.0         Canada  0.982  0.904  0.921                84
# 9   9.0    New Zealand  0.961  0.894   0.93              83.6
#
#   M_Life Expectancy F_Exp Education Years M_Exp Education Years  \
# 0              79.5                  18.2                  16.8
# 1              80.3                  20.7                  19.7
# 2              80.8                  15.7                  15.9
# ...

# %%
genderDev_DF = genderDev_DF.fillna(0)
genderDev_DF.head(10)
# Out:
#    Rank        Country    GDI  F_HDI  M_HDI F_Life Expectancy  \
# 0   1.0         Norway  0.996   0.94  0.944              83.6
# 1   2.0      Australia  0.976  0.922  0.945              84.5
# 2   3.0    Switzerland   0.95  0.898  0.945                85
# 3   4.0        Denmark  0.977  0.912  0.934              82.2
# 4   5.0    Netherlands  0.947  0.893  0.943              83.3
# 5   6.0        Germany  0.963  0.901  0.936              83.3
# 6   6.0        Ireland  0.973  0.901  0.926                83
# 7   8.0  United States  0.995  0.911  0.916              81.4
# 8   9.0         Canada  0.982  0.904  0.921                84
# 9   9.0    New Zealand  0.961  0.894   0.93              83.6
#
#   M_Life Expectancy F_Exp Education Years M_Exp Education Years  \
# 0              79.5                  18.2                  16.8
# 1              80.3                  20.7                  19.7
# 2              80.8                  15.7                  15.9
# ...

# %%
genderDevList = ['Rank', 'GDI', 'F_HDI', 'M_HDI', 'F_Life Expectancy', 
                 'M_Life Expectancy', 'F_Exp Education Years', 'M_Exp Education Years', 
                 'F_Mean Educ Years', 'M_Mean Educ Years', 'F_Est GNI', 'M_Est GNI']
for col in genderDevList:
  if col in pd.DataFrame(genderDev_DF).columns:
    genderDev_DF[col] = pd.to_numeric(genderDev_DF[col])

# %%
genderDev_DF.dtypes
# Out:
# Rank                     float64
# Country                   object
# GDI                      float64
# F_HDI                    float64
# M_HDI                    float64
# F_Life Expectancy        float64
# M_Life Expectancy        float64
# F_Exp Education Years    float64
# M_Exp Education Years    float64
# F_Mean Educ Years        float64
# M_Mean Educ Years        float64
# F_Est GNI                  int64
# M_Est GNI                  int64
# dtype: object

# %%
genderDev_DF.describe()
# Out:
#              Rank         GDI       F_HDI       M_HDI  F_Life Expectancy  \
# count  195.000000  195.000000  195.000000  195.000000         195.000000
# mean    90.928205    0.800821    0.580082    0.617964          71.411282
# std     56.261310    0.328786    0.279439    0.281749          14.545821
# min      0.000000    0.000000    0.000000    0.000000           0.000000
# 25%     42.500000    0.835500    0.441000    0.526500          66.500000
# 50%     90.000000    0.943000    0.671000    0.716000          75.700000
# 75%    139.500000    0.975000    0.788000    0.802000          78.950000
# max    188.000000    1.030000    0.940000    0.945000          86.800000
#
#        M_Life Expectancy  F_Exp Education Years  M_Exp Education Years  \
# count         195.000000             195.000000             195.000000
# mean           66.800000              12.153846              12.078974
# std            13.377408               4.567153               4.099135
# ...

# %% [markdown]
# ### Gender Inequality

# %%
genderIneq_origDF = pd.read_csv('/content/gender_inequality.csv')
genderIneq_origDF
# Out:
#      GII Rank                          Country Gender Inequality Index (GII)  \
# 0         1.0                           Norway                         0.067
# 1         2.0                        Australia                          0.11
# 2         3.0                      Switzerland                         0.028
# 3         4.0                          Denmark                         0.048
# 4         5.0                      Netherlands                         0.062
# ..        ...                              ...                           ...
# 190       NaN          Europe and Central Asia                           0.3
# 191       NaN  Latin America and the Caribbean                         0.415
# 192       NaN                       South Asia                         0.536
# 193       NaN               Sub-Saharan Africa                         0.575
# 194       NaN                            World                         0.449
#
# ...

# %%
genderIneq_DF = genderIneq_origDF.copy()
genderIneq_DF.head(10)
# Out:
#    GII Rank        Country Gender Inequality Index (GII)  \
# 0       1.0         Norway                         0.067
# 1       2.0      Australia                          0.11
# 2       3.0    Switzerland                         0.028
# 3       4.0        Denmark                         0.048
# 4       5.0    Netherlands                         0.062
# 5       6.0        Germany                         0.041
# 6       6.0        Ireland                         0.113
# 7       8.0  United States                          0.28
# 8       9.0         Canada                         0.129
# 9       9.0    New Zealand                         0.157
#
#   Maternal Mortality Ratio Adolescent Birth Rate  \
# 0                        4                   7.8
# 1                        6                  12.1
# 2                        6                   1.9
# 3                        5                   5.1
# 4                        6                   6.2
# ...

# %%
genderIneq_DF.columns = ['Rank', 'Country', 'GII', 'MMR', 'ABR', 'PRP', 'F_PopHS',
                             'M_PopHS', 'F_Labor Force', 'M_Labor Force']
genderIneq_DF.columns
# Out:
# Index(['Rank', 'Country', 'GII', 'MMR', 'ABR', 'PRP', 'F_PopHS', 'M_PopHS',
#        'F_Labor Force', 'M_Labor Force'],
#       dtype='object')

# %%
genderIneq_DF.isnull().sum()
# Out:
# Rank             7
# Country          0
# GII              0
# MMR              0
# ABR              0
# PRP              0
# F_PopHS          0
# M_PopHS          0
# F_Labor Force    0
# M_Labor Force    0
# dtype: int64

# %%
genderIneq_DF = genderIneq_DF.replace('..', '0')
genderIneq_DF.head(10)
# Out:
#    Rank        Country    GII MMR   ABR   PRP F_PopHS M_PopHS F_Labor Force  \
# 0   1.0         Norway  0.067   4   7.8  39.6    97.4    96.7          61.2
# 1   2.0      Australia   0.11   6  12.1  30.5    94.3    94.6          58.8
# 2   3.0    Switzerland  0.028   6   1.9  28.5      95    96.6          61.8
# 3   4.0        Denmark  0.048   5   5.1    38    95.5    96.6          58.7
# 4   5.0    Netherlands  0.062   6   6.2  36.9    87.7    90.5          58.5
# 5   6.0        Germany  0.041   7   3.8  36.9    96.3      97          53.6
# 6   6.0        Ireland  0.113   9   8.2  19.9    80.5    78.6          53.1
# 7   8.0  United States   0.28  28    31  19.4    95.1    94.8          56.3
# 8   9.0         Canada  0.129  11  14.5  28.2     100     100          61.6
# 9   9.0    New Zealand  0.157   8  25.3  31.4      95    95.3            62
#
#   M_Labor Force
# 0          68.7
# 1          71.8
# 2          74.9
# 3          66.4
# 4          70.6
# 5          66.4
# ...

# %%
genderIneq_DF = genderIneq_DF.fillna(0)
genderIneq_DF.head(10)
# Out:
#    Rank        Country    GII MMR   ABR   PRP F_PopHS M_PopHS F_Labor Force  \
# 0   1.0         Norway  0.067   4   7.8  39.6    97.4    96.7          61.2
# 1   2.0      Australia   0.11   6  12.1  30.5    94.3    94.6          58.8
# 2   3.0    Switzerland  0.028   6   1.9  28.5      95    96.6          61.8
# 3   4.0        Denmark  0.048   5   5.1    38    95.5    96.6          58.7
# 4   5.0    Netherlands  0.062   6   6.2  36.9    87.7    90.5          58.5
# 5   6.0        Germany  0.041   7   3.8  36.9    96.3      97          53.6
# 6   6.0        Ireland  0.113   9   8.2  19.9    80.5    78.6          53.1
# 7   8.0  United States   0.28  28    31  19.4    95.1    94.8          56.3
# 8   9.0         Canada  0.129  11  14.5  28.2     100     100          61.6
# 9   9.0    New Zealand  0.157   8  25.3  31.4      95    95.3            62
#
#   M_Labor Force
# 0          68.7
# 1          71.8
# 2          74.9
# 3          66.4
# 4          70.6
# 5          66.4
# ...

# %%
genderIneqList = ['Rank', 'GII', 'MMR', 'ABR', 'PRP', 'F_PopHS', 'M_PopHS', 
                  'F_Labor Force', 'M_Labor Force']
for col in genderIneqList:
  if col in genderIneq_DF.columns:
    genderIneq_DF[col] = pd.to_numeric(genderIneq_DF[col])

# %%
genderIneq_DF.dtypes
# Out:
# Rank             float64
# Country           object
# GII              float64
# MMR                int64
# ABR              float64
# PRP              float64
# F_PopHS          float64
# M_PopHS          float64
# F_Labor Force    float64
# M_Labor Force    float64
# dtype: object

# %%
genderIneq_DF.describe()
# Out:
#              Rank         GII          MMR         ABR         PRP  \
# count  195.000000  195.000000   195.000000  195.000000  195.000000
# mean    90.928205    0.306933   154.861538   48.284103   20.284615
# std     56.261310    0.221314   210.771597   40.974434   11.605014
# min      0.000000    0.000000     0.000000    0.000000    0.000000
# 25%     42.500000    0.097500    11.500000   14.500000   12.300000
# 50%     90.000000    0.328000    58.000000   38.800000   19.300000
# 75%    139.500000    0.493000   210.000000   71.100000   26.900000
# max    188.000000    0.744000  1100.000000  204.800000   57.500000
#
#           F_PopHS     M_PopHS  F_Labor Force  M_Labor Force
# count  195.000000  195.000000     195.000000     195.000000
# mean    47.497436   52.250769      49.643077      70.522051
# std     33.648263   32.737395      19.912199      19.143936
# min      0.000000    0.000000       0.000000       0.000000
# 25%     15.750000   26.700000      43.050000      67.750000
# ...

# %% [markdown]
# ## Historical Index

# %%
histIndex_origDF = pd.read_csv('/content/historical_index.csv')
histIndex_origDF
# Out:
#      HDI Rank                          Country Human Development Index (1990)  \
# 0         1.0                           Norway                          0.849
# 1         2.0                        Australia                          0.865
# 2         3.0                      Switzerland                          0.831
# 3         4.0                          Denmark                          0.799
# 4         5.0                      Netherlands                          0.829
# ..        ...                              ...                            ...
# 190       NaN          Europe and Central Asia                          0.651
# 191       NaN  Latin America and the Caribbean                          0.625
# 192       NaN                       South Asia                          0.437
# 193       NaN               Sub-Saharan Africa                          0.400
# 194       NaN                            World                          0.597
#
# ...

# %%
histIndex_DF = histIndex_origDF.copy()
histIndex_origDF.head(10)
# Out:
#    HDI Rank        Country Human Development Index (1990)  \
# 0       1.0         Norway                          0.849
# 1       2.0      Australia                          0.865
# 2       3.0    Switzerland                          0.831
# 3       4.0        Denmark                          0.799
# 4       5.0    Netherlands                          0.829
# 5       6.0        Germany                          0.801
# 6       6.0        Ireland                          0.770
# 7       8.0  United States                          0.859
# 8       9.0         Canada                          0.849
# 9       9.0    New Zealand                          0.820
#
#   Human Development Index (2000)  Human Development Index (2010)  \
# 0                          0.917                           0.940
# 1                          0.898                           0.927
# 2                          0.888                           0.924
# ...

# %%
histIndex_DF.columns = ['Rank', 'Country', 'HDI(1990)', 'HDI(2000)', 'HDI(2010)',
                            'HDI(2011)', 'HDI(2012)', 'HDI(2013)', 'HDI(2014)']
histIndex_DF.columns
# Out:
# Index(['Rank', 'Country', 'HDI(1990)', 'HDI(2000)', 'HDI(2010)', 'HDI(2011)',
#        'HDI(2012)', 'HDI(2013)', 'HDI(2014)'],
#       dtype='object')

# %%
histIndex_DF.isnull().sum()
# Out:
# Rank         7
# Country      0
# HDI(1990)    0
# HDI(2000)    0
# HDI(2010)    0
# HDI(2011)    0
# HDI(2012)    0
# HDI(2013)    0
# HDI(2014)    0
# dtype: int64

# %%
histIndex_DF = histIndex_DF.replace('..', '0')
histIndex_DF.head(10)
# Out:
#    Rank        Country HDI(1990) HDI(2000)  HDI(2010)  HDI(2011)  HDI(2012)  \
# 0   1.0         Norway     0.849     0.917      0.940      0.941      0.942
# 1   2.0      Australia     0.865     0.898      0.927      0.930      0.932
# 2   3.0    Switzerland     0.831     0.888      0.924      0.925      0.927
# 3   4.0        Denmark     0.799     0.862      0.908      0.920      0.921
# 4   5.0    Netherlands     0.829     0.877      0.909      0.919      0.920
# 5   6.0        Germany     0.801     0.855      0.906      0.911      0.915
# 6   6.0        Ireland     0.770     0.861      0.908      0.909      0.910
# 7   8.0  United States     0.859     0.883      0.909      0.911      0.912
# 8   9.0         Canada     0.849     0.867      0.903      0.909      0.910
# 9   9.0    New Zealand     0.820     0.874      0.905      0.907      0.909
#
#    HDI(2013)  HDI(2014)
# 0      0.942      0.944
# 1      0.933      0.935
# 2      0.928      0.930
# 3      0.923      0.923
# ...

# %%
histIndex_DF = histIndex_DF.fillna(0)
histIndex_DF.head(10)
# Out:
#    Rank        Country HDI(1990) HDI(2000)  HDI(2010)  HDI(2011)  HDI(2012)  \
# 0   1.0         Norway     0.849     0.917      0.940      0.941      0.942
# 1   2.0      Australia     0.865     0.898      0.927      0.930      0.932
# 2   3.0    Switzerland     0.831     0.888      0.924      0.925      0.927
# 3   4.0        Denmark     0.799     0.862      0.908      0.920      0.921
# 4   5.0    Netherlands     0.829     0.877      0.909      0.919      0.920
# 5   6.0        Germany     0.801     0.855      0.906      0.911      0.915
# 6   6.0        Ireland     0.770     0.861      0.908      0.909      0.910
# 7   8.0  United States     0.859     0.883      0.909      0.911      0.912
# 8   9.0         Canada     0.849     0.867      0.903      0.909      0.910
# 9   9.0    New Zealand     0.820     0.874      0.905      0.907      0.909
#
#    HDI(2013)  HDI(2014)
# 0      0.942      0.944
# 1      0.933      0.935
# 2      0.928      0.930
# 3      0.923      0.923
# ...

# %%
histIndexList = ['Rank', 'HDI(1990)', 'HDI(2000)', 'HDI(2010)', 'HDI(2011)', 
                 'HDI(2012)', 'HDI(2013)', 'HDI(2014)']
for col in histIndexList:
  if col in histIndex_DF.columns:
    histIndex_DF[col] = pd.to_numeric(histIndex_DF[col])

# %%
histIndex_DF.dtypes
# Out:
# Rank         float64
# Country       object
# HDI(1990)    float64
# HDI(2000)    float64
# HDI(2010)    float64
# HDI(2011)    float64
# HDI(2012)    float64
# HDI(2013)    float64
# HDI(2014)    float64
# dtype: object

# %%
histIndex_DF.describe()
# Out:
#              Rank   HDI(1990)   HDI(2000)   HDI(2010)   HDI(2011)   HDI(2012)  \
# count  195.000000  195.000000  195.000000  195.000000  195.000000  195.000000
# mean    90.928205    0.456328    0.554769    0.678964    0.683159    0.687123
# std     56.261310    0.288159    0.253729    0.155295    0.154210    0.153649
# min      0.000000    0.000000    0.000000    0.326000    0.333000    0.342000
# 25%     42.500000    0.253000    0.425500    0.550000    0.559500    0.567500
# 50%     90.000000    0.553000    0.623000    0.711000    0.713000    0.718000
# 75%    139.500000    0.693500    0.736500    0.793500    0.795500    0.797000
# max    188.000000    0.865000    0.917000    0.940000    0.941000    0.942000
#
#         HDI(2013)   HDI(2014)
# count  195.000000  195.000000
# mean     0.689487    0.691846
# std      0.153172    0.152638
# min      0.345000    0.348000
# 25%      0.573500    0.577000
# 50%      0.720000    0.721000
# 75%      0.799000    0.800000
# ...

# %% [markdown]
# ## Human Development Index (HDI)

# %% [markdown]
# ### Human Development

# %%
humanDev_origDF = pd.read_csv('/content/human_development.csv')
humanDev_origDF
# Out:
#      HDI Rank                          Country  Human Development Index (HDI)  \
# 0         1.0                           Norway                          0.944
# 1         2.0                        Australia                          0.935
# 2         3.0                      Switzerland                          0.930
# 3         4.0                          Denmark                          0.923
# 4         5.0                      Netherlands                          0.922
# ..        ...                              ...                            ...
# 190       NaN          Europe and Central Asia                          0.748
# 191       NaN  Latin America and the Caribbean                          0.748
# 192       NaN                       South Asia                          0.607
# 193       NaN               Sub-Saharan Africa                          0.518
# 194       NaN                            World                          0.711
#
# ...

# %%
humanDev_DF = humanDev_origDF.copy()
humanDev_DF.head(10)
# Out:
#    HDI Rank        Country  Human Development Index (HDI)  \
# 0       1.0         Norway                          0.944
# 1       2.0      Australia                          0.935
# 2       3.0    Switzerland                          0.930
# 3       4.0        Denmark                          0.923
# 4       5.0    Netherlands                          0.922
# 5       6.0        Germany                          0.916
# 6       6.0        Ireland                          0.916
# 7       8.0  United States                          0.915
# 8       9.0         Canada                          0.913
# 9       9.0    New Zealand                          0.913
#
#    Life Expectancy at Birth  Expected Years of Education  \
# 0                      81.6                         17.5
# 1                      82.4                         20.2
# 2                      83.0                         15.8
# 3                      80.2                         18.7
# ...

# %%
humanDev_DF.columns = ['Rank', 'Country', 'HDI', 'Life Expectancy', 'Exp Educ Years', 
                       'Mean Educ Years', 'GNI', 'GNI_R-HDI_R']
humanDev_DF.columns
# Out:
# Index(['Rank', 'Country', 'HDI', 'Life Expectancy', 'Exp Educ Years',
#        'Mean Educ Years', 'GNI', 'GNI_R-HDI_R'],
#       dtype='object')

# %%
humanDev_DF.isnull().sum()
# Out:
# Rank               7
# Country            0
# HDI                0
# Life Expectancy    0
# Exp Educ Years     0
# Mean Educ Years    0
# GNI                0
# GNI_R-HDI_R        7
# dtype: int64

# %%
humanDev_DF = humanDev_DF.replace('..', '0')
humanDev_DF.head(10)
# Out:
#    Rank        Country    HDI  Life Expectancy  Exp Educ Years  \
# 0   1.0         Norway  0.944             81.6            17.5
# 1   2.0      Australia  0.935             82.4            20.2
# 2   3.0    Switzerland  0.930             83.0            15.8
# 3   4.0        Denmark  0.923             80.2            18.7
# 4   5.0    Netherlands  0.922             81.6            17.9
# 5   6.0        Germany  0.916             80.9            16.5
# 6   6.0        Ireland  0.916             80.9            18.6
# 7   8.0  United States  0.915             79.1            16.5
# 8   9.0         Canada  0.913             82.0            15.9
# 9   9.0    New Zealand  0.913             81.8            19.2
#
#    Mean Educ Years     GNI  GNI_R-HDI_R
# 0             12.6  64,992          5.0
# 1             13.0  42,261         17.0
# 2             12.8  56,431          6.0
# 3             12.7  44,025         11.0
# 4             11.9  45,435          9.0
# ...

# %%
humanDev_DF['GNI'] = humanDev_DF['GNI'].replace(',', '', regex=True).astype(float)

# %%
humanDev_DF = humanDev_DF.fillna(0)
humanDev_DF.head(10)
# Out:
#    Rank        Country    HDI  Life Expectancy  Exp Educ Years  \
# 0   1.0         Norway  0.944             81.6            17.5
# 1   2.0      Australia  0.935             82.4            20.2
# 2   3.0    Switzerland  0.930             83.0            15.8
# 3   4.0        Denmark  0.923             80.2            18.7
# 4   5.0    Netherlands  0.922             81.6            17.9
# 5   6.0        Germany  0.916             80.9            16.5
# 6   6.0        Ireland  0.916             80.9            18.6
# 7   8.0  United States  0.915             79.1            16.5
# 8   9.0         Canada  0.913             82.0            15.9
# 9   9.0    New Zealand  0.913             81.8            19.2
#
#    Mean Educ Years      GNI  GNI_R-HDI_R
# 0             12.6  64992.0          5.0
# 1             13.0  42261.0         17.0
# 2             12.8  56431.0          6.0
# 3             12.7  44025.0         11.0
# 4             11.9  45435.0          9.0
# ...

# %%
humanDevList = ['Rank', 'HDI', 'Life Expectancy', 'Exp Educ Years', 'Mean Educ Years', 'GNI_R-HDI_R']
for col in humanDevList:
  if col in pd.DataFrame(humanDev_DF).columns:
    humanDev_DF[col] = pd.to_numeric(humanDev_DF[col])

# %%
humanDev_DF.dtypes
# Out:
# Rank               float64
# Country             object
# HDI                float64
# Life Expectancy    float64
# Exp Educ Years     float64
# Mean Educ Years    float64
# GNI                float64
# GNI_R-HDI_R        float64
# dtype: object

# %%
humanDev_DF.describe()
# Out:
#              Rank         HDI  Life Expectancy  Exp Educ Years  \
# count  195.000000  195.000000       195.000000      195.000000
# mean    90.928205    0.691846        71.067179       12.861026
# std     56.261310    0.152638         8.290334        2.831163
# min      0.000000    0.348000        49.000000        4.100000
# 25%     42.500000    0.577000        65.750000       11.100000
# 50%     90.000000    0.721000        73.100000       13.100000
# 75%    139.500000    0.800000        76.800000       14.900000
# max    188.000000    0.944000        84.000000       20.200000
#
#        Mean Educ Years            GNI  GNI_R-HDI_R
# count       195.000000     195.000000   195.000000
# mean          8.078974   16801.317949     0.179487
# std           3.055099   18503.516065    17.010718
# min           1.400000     581.000000   -84.000000
# 25%           5.550000    3771.500000    -8.500000
# 50%           8.400000   10939.000000     1.000000
# ...

# %% [markdown]
# ### Inequality Adjusted

# %%
ineqAdj_origDF = pd.read_csv('/content/inequality_adjusted.csv')
ineqAdj_origDF
# Out:
#      IHDI Rank                          Country  \
# 0          1.0                           Norway
# 1          2.0                        Australia
# 2          3.0                      Switzerland
# 3          4.0                          Denmark
# 4          5.0                      Netherlands
# ..         ...                              ...
# 190        NaN          Europe and Central Asia
# 191        NaN  Latin America and the Caribbean
# 192        NaN                       South Asia
# 193        NaN               Sub-Saharan Africa
# 194        NaN                            World
#
#      Human Development Index (HDI) Inequality-adjusted HDI (IHDI)  \
# 0                            0.944                          0.893
# 1                            0.935                          0.858
# 2                            0.930                          0.861
# 3                            0.923                          0.856
# ...

# %%
ineqAdj_DF = ineqAdj_origDF.copy()
ineqAdj_DF.head(10)
# Out:
#    IHDI Rank        Country  Human Development Index (HDI)  \
# 0        1.0         Norway                          0.944
# 1        2.0      Australia                          0.935
# 2        3.0    Switzerland                          0.930
# 3        4.0        Denmark                          0.923
# 4        5.0    Netherlands                          0.922
# 5        6.0        Germany                          0.916
# 6        6.0        Ireland                          0.916
# 7        8.0  United States                          0.915
# 8        9.0         Canada                          0.913
# 9        9.0    New Zealand                          0.913
#
#   Inequality-adjusted HDI (IHDI) IHDI Loss Percent IHDI Rank Difference  \
# 0                          0.893               5.4                    0
# 1                          0.858               8.2                   -2
# 2                          0.861               7.4                    0
# ...

# %%
ineqAdj_DF.columns = ['Rank', 'Country', 'HDI', 'IHDI', 'IHDI Loss', 'IHDI Diff', 'Coeff Human Ineq',
                      'Ineq Life Exp', 'IHDI Life Exp', 'Education Ineq', 'Education IHDI',
                      'Income Ineq', 'Income IHDI', 'Income Ineq(Quantile)', 
                      'Income Ineq(Palma)', 'Income Ineq(Gini)']
ineqAdj_DF.columns
# Out:
# Index(['Rank', 'Country', 'HDI', 'IHDI', 'IHDI Loss', 'IHDI Diff',
#        'Coeff Human Ineq', 'Ineq Life Exp', 'IHDI Life Exp', 'Education Ineq',
#        'Education IHDI', 'Income Ineq', 'Income IHDI', 'Income Ineq(Quantile)',
#        'Income Ineq(Palma)', 'Income Ineq(Gini)'],
#       dtype='object')

# %%
ineqAdj_DF.isnull().sum()
# Out:
# Rank                     7
# Country                  0
# HDI                      0
# IHDI                     0
# IHDI Loss                0
# IHDI Diff                7
# Coeff Human Ineq         0
# Ineq Life Exp            0
# IHDI Life Exp            0
# Education Ineq           0
# Education IHDI           0
# Income Ineq              0
# Income IHDI              0
# Income Ineq(Quantile)    7
# Income Ineq(Palma)       7
# Income Ineq(Gini)        7
# dtype: int64

# %%
ineqAdj_DF = ineqAdj_DF.replace('..', '0')
ineqAdj_DF.head(10)
# Out:
#    Rank        Country    HDI   IHDI IHDI Loss IHDI Diff Coeff Human Ineq  \
# 0   1.0         Norway  0.944  0.893       5.4         0              5.3
# 1   2.0      Australia  0.935  0.858       8.2        -2              7.9
# 2   3.0    Switzerland  0.930  0.861       7.4         0              7.3
# 3   4.0        Denmark  0.923  0.856       7.3        -1              7.1
# 4   5.0    Netherlands  0.922  0.861       6.6         3              6.5
# 5   6.0        Germany  0.916  0.853       6.9         0              6.7
# 6   6.0        Ireland  0.916  0.836       8.6        -3              8.5
# 7   8.0  United States  0.915  0.760      17.0       -20             15.7
# 8   9.0         Canada  0.913  0.832       8.8        -2              8.6
# 9   9.0    New Zealand  0.913      0         0         0                0
#
#   Ineq Life Exp IHDI Life Exp Education Ineq Education IHDI Income Ineq  \
# 0           3.4         0.916            2.3          0.886        10.2
# ...

# %%
ineqAdj_DF = ineqAdj_DF.fillna(0)
ineqAdj_DF.head(10)
# Out:
#    Rank        Country    HDI   IHDI IHDI Loss IHDI Diff Coeff Human Ineq  \
# 0   1.0         Norway  0.944  0.893       5.4         0              5.3
# 1   2.0      Australia  0.935  0.858       8.2        -2              7.9
# 2   3.0    Switzerland  0.930  0.861       7.4         0              7.3
# 3   4.0        Denmark  0.923  0.856       7.3        -1              7.1
# 4   5.0    Netherlands  0.922  0.861       6.6         3              6.5
# 5   6.0        Germany  0.916  0.853       6.9         0              6.7
# 6   6.0        Ireland  0.916  0.836       8.6        -3              8.5
# 7   8.0  United States  0.915  0.760      17.0       -20             15.7
# 8   9.0         Canada  0.913  0.832       8.8        -2              8.6
# 9   9.0    New Zealand  0.913      0         0         0                0
#
#   Ineq Life Exp IHDI Life Exp Education Ineq Education IHDI Income Ineq  \
# 0           3.4         0.916            2.3          0.886        10.2
# ...

# %%
ineqAdjList = ['Rank', 'HDI', 'IHDI', 'IHDI Loss', 'IHDI Diff', 'Coeff Human Ineq', 
               'Ineq Life Exp', 'IHDI Life Exp', 'Education Ineq', 'Education IHDI', 
               'Income Ineq', 'Income IHDI', 'Income Ineq(Quantile)', 'Income Ineq(Palma)', 'Income Ineq(Gini)']
for col in ineqAdjList:
  if col in ineqAdj_DF.columns:
    ineqAdj_DF[col] = pd.to_numeric(ineqAdj_DF[col])

# %%
ineqAdj_DF.dtypes
# Out:
# Rank                     float64
# Country                   object
# HDI                      float64
# IHDI                     float64
# IHDI Loss                float64
# IHDI Diff                  int64
# Coeff Human Ineq         float64
# Ineq Life Exp            float64
# IHDI Life Exp            float64
# Education Ineq           float64
# Education IHDI           float64
# Income Ineq              float64
# Income IHDI              float64
# Income Ineq(Quantile)    float64
# Income Ineq(Palma)       float64
# Income Ineq(Gini)        float64
# dtype: object

# %%
ineqAdj_DF.describe()
# Out:
#              Rank         HDI        IHDI   IHDI Loss   IHDI Diff  \
# count  195.000000  195.000000  195.000000  195.000000  195.000000
# mean    90.928205    0.691846    0.445749   17.408718   -0.123077
# std     56.261310    0.152638    0.273267   12.714327    7.415867
# min      0.000000    0.348000    0.000000    0.000000  -41.000000
# 25%     42.500000    0.577000    0.278000    7.350000   -2.000000
# 50%     90.000000    0.721000    0.488000   16.400000    0.000000
# 75%    139.500000    0.800000    0.656000   28.650000    3.000000
# max    188.000000    0.944000    0.893000   46.700000   20.000000
#
#        Coeff Human Ineq  Ineq Life Exp  IHDI Life Exp  Education Ineq  \
# count        195.000000     195.000000     195.000000      195.000000
# mean          17.033846      17.085128       0.644149       17.744615
# std           12.412626      12.824362       0.216547       15.472430
# min            0.000000       0.000000       0.000000        0.000000
# ...

# %% [markdown]
# ## Multidimensional Poverty

# %%
multiPoverty_origDF = pd.read_csv('/content/multidimensional_poverty.csv')
multiPoverty_origDF
# Out:
#          Country Year and Survey  Multidimensional Poverty Index (MPI, HDRO)  \
# 0    Afghanistan     2010/2011 M                                       0.293
# 1        Albania     2008/2009 D                                       0.005
# 2      Argentina          2005 N                                       0.015
# 3        Armenia          2010 D                                       0.002
# 4     Azerbaijan          2006 D                                       0.009
# ..           ...             ...                                         ...
# 96       Vanuatu          2007 M                                       0.135
# 97      Viet Nam     2010/2011 M                                       0.026
# 98         Yemen          2013 D                                       0.200
# 99        Zambia     2013/2014 D                                       0.264
# 100     Zimbabwe          2014 M                                       0.128
#
# ...

# %%
multiPoverty_DF = multiPoverty_origDF.copy()
multiPoverty_DF.head(10)
# Out:
#        Country Year and Survey  Multidimensional Poverty Index (MPI, HDRO)  \
# 0  Afghanistan     2010/2011 M                                       0.293
# 1      Albania     2008/2009 D                                       0.005
# 2    Argentina          2005 N                                       0.015
# 3      Armenia          2010 D                                       0.002
# 4   Azerbaijan          2006 D                                       0.009
# 5   Bangladesh          2011 D                                       0.237
# 6     Barbados          2012 M                                       0.004
# 7      Belarus          2005 M                                       0.001
# 8       Belize          2011 M                                       0.030
# 9        Benin     2011/2012 D                                       0.343
#
#    MPI HDRO Percent  Multidimensional Poverty Index (MPI, 2010)  \
# 0              58.8                                       0.353
# ...

# %%
multiPoverty_DF.columns = ['Country', 'Year-Survey', 'MPI', 'MPI HDRO', 'MPI(2010)', 
                           'MPI(2010) Percent', 'Population Multi Poverty', 'Deprivation Intensity', 
                           'Educational Deprivation', 'Health Deprivation', 
                           'Living Standards', 'Population Below Pov Line', 
                           'Population Below 1.25']
multiPoverty_DF.columns
# Out:
# Index(['Country', 'Year-Survey', 'MPI', 'MPI HDRO', 'MPI(2010)',
#        'MPI(2010) Percent', 'Population Multi Poverty',
#        'Deprivation Intensity', 'Educational Deprivation',
#        'Health Deprivation', 'Living Standards', 'Population Below Pov Line',
#        'Population Below 1.25'],
#       dtype='object')

# %%
multiPoverty_DF.isnull().sum()
# Out:
# Country                      0
# Year-Survey                  0
# MPI                          0
# MPI HDRO                     0
# MPI(2010)                    2
# MPI(2010) Percent            2
# Population Multi Poverty     0
# Deprivation Intensity        0
# Educational Deprivation      0
# Health Deprivation           0
# Living Standards             0
# Population Below Pov Line    0
# Population Below 1.25        0
# dtype: int64

# %%
multiPoverty_DF = multiPoverty_DF.replace('..', '0')
multiPoverty_DF.head(10)
# Out:
#        Country  Year-Survey    MPI  MPI HDRO  MPI(2010)  MPI(2010) Percent  \
# 0  Afghanistan  2010/2011 M  0.293      58.8      0.353               66.2
# 1      Albania  2008/2009 D  0.005       1.2      0.005                1.4
# 2    Argentina       2005 N  0.015       3.7      0.011                2.9
# 3      Armenia       2010 D  0.002       0.6      0.001                0.3
# 4   Azerbaijan       2006 D  0.009       2.4      0.021                5.3
# 5   Bangladesh       2011 D  0.237      49.5      0.253               51.3
# 6     Barbados       2012 M  0.004       1.2      0.003                0.9
# 7      Belarus       2005 M  0.001       0.4      0.000                0.0
# 8       Belize       2011 M  0.030       7.4      0.018                4.6
# 9        Benin  2011/2012 D  0.343      64.2      0.307               62.2
#
#   Population Multi Poverty  Deprivation Intensity  Educational Deprivation  \
# ...

# %%
multiPoverty_DF = multiPoverty_DF.fillna(0)
multiPoverty_DF.head(10)
# Out:
#        Country  Year-Survey    MPI  MPI HDRO  MPI(2010)  MPI(2010) Percent  \
# 0  Afghanistan  2010/2011 M  0.293      58.8      0.353               66.2
# 1      Albania  2008/2009 D  0.005       1.2      0.005                1.4
# 2    Argentina       2005 N  0.015       3.7      0.011                2.9
# 3      Armenia       2010 D  0.002       0.6      0.001                0.3
# 4   Azerbaijan       2006 D  0.009       2.4      0.021                5.3
# 5   Bangladesh       2011 D  0.237      49.5      0.253               51.3
# 6     Barbados       2012 M  0.004       1.2      0.003                0.9
# 7      Belarus       2005 M  0.001       0.4      0.000                0.0
# 8       Belize       2011 M  0.030       7.4      0.018                4.6
# 9        Benin  2011/2012 D  0.343      64.2      0.307               62.2
#
#   Population Multi Poverty  Deprivation Intensity  Educational Deprivation  \
# ...

# %%
multiPoverty_DF['Population Multi Poverty'] = multiPoverty_DF['Population Multi Poverty'].replace(',', '', regex=True).astype(float)

# %%
multiPovertyList = ['MPI HDRO', 'MPI(2010)', 'MPI(2010) Percent', 'Deprivation Intensity', 
                    'Educational Deprivation', 'Health Deprivation', 'Living Standards', 
                    'Population Below Pov Line', 'Population Below 1.25']
for col in multiPovertyList:
  if col in pd.DataFrame(multiPoverty_DF).columns:
    multiPoverty_DF[col] = pd.to_numeric(multiPoverty_DF[col])

# %%
multiPoverty_DF.dtypes
# Out:
# Country                       object
# Year-Survey                   object
# MPI                          float64
# MPI HDRO                     float64
# MPI(2010)                    float64
# MPI(2010) Percent            float64
# Population Multi Poverty     float64
# Deprivation Intensity        float64
# Educational Deprivation      float64
# Health Deprivation           float64
# Living Standards             float64
# Population Below Pov Line    float64
# Population Below 1.25        float64
# dtype: object

# %%
multiPoverty_DF.describe()
# Out:
#               MPI    MPI HDRO   MPI(2010)  MPI(2010) Percent  \
# count  101.000000  101.000000  101.000000         101.000000
# mean     0.170149   32.599010    0.169525          31.854455
# std      0.169847   29.718097    0.175961          29.978344
# min      0.001000    0.400000    0.000000           0.000000
# 25%      0.015000    3.700000    0.013000           3.500000
# 50%      0.127000   26.900000    0.089000          20.500000
# 75%      0.290000   55.600000    0.309000          57.800000
# max      0.584000   89.800000    0.605000          91.100000
#
#        Population Multi Poverty  Deprivation Intensity  \
# count                101.000000             101.000000
# mean               15016.495050              45.852475
# std                64535.673304               7.588631
# min                    2.000000              33.700000
# 25%                  173.000000              39.100000
# 50%                 2447.000000              45.100000
# ...

# %% [markdown]
# # Descriptive Analytics

# %% [markdown]
# ## Gender Development Index (GDI)

# %% [markdown]
# ### Gender Development

# %%
sortedGDI = genderDev_DF.sort_values(by=['GDI'], ascending=False).head(10)
sortedGDI = sortedGDI[['Country', 'GDI']]
sortedGDI
# Out:
#                                Country    GDI
# 36                           Lithuania  1.030
# 29                             Estonia  1.030
# 70  Venezuela (Bolivarian Republic of)  1.030
# 45                              Latvia  1.029
# 91                            Mongolia  1.028
# 49                             Belarus  1.021
# 50                  Russian Federation  1.019
# 53                             Uruguay  1.018
# 56                            Barbados  1.018
# 85                             Armenia  1.008

# %%
plt.title('Gender Development Index')
sns.lineplot(sortedGDI['Country'], sortedGDI['GDI'], color='peru')
plt.xticks(rotation=90)

plt.savefig('GDI Top 10.png', dpi=300, bbox_inches='tight')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sortedHDI = genderDev_DF.sort_values(by=['F_HDI', 'M_HDI'], ascending=False).head(10)
sortedHDI = sortedHDI[['Country', 'F_HDI', 'M_HDI']]
sortedHDI
# Out:
#           Country  F_HDI  M_HDI
# 0          Norway  0.940  0.944
# 1       Australia  0.922  0.945
# 3         Denmark  0.912  0.934
# 7   United States  0.911  0.916
# 13         Sweden  0.906  0.906
# 8          Canada  0.904  0.921
# 5         Germany  0.901  0.936
# 6         Ireland  0.901  0.926
# 2     Switzerland  0.898  0.945
# 10      Singapore  0.898  0.912

# %%
plt.ylabel('HDI')
plt.title('Human Development Index')
sns.lineplot(sortedHDI['Country'], sortedHDI['F_HDI'], color='lightcoral', label='Female')
sns.lineplot(sortedHDI['Country'], sortedHDI['M_HDI'], color='darkslategray', label='Male')
plt.xticks(rotation=90)

plt.savefig('HDI Top 10.png', dpi=300, bbox_inches='tight')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sortedLifeExp = genderDev_DF.sort_values(by=['F_Life Expectancy', 'M_Life Expectancy'], ascending=False).head(10)
sortedLifeExp = sortedLifeExp[['Country', 'F_Life Expectancy', 'M_Life Expectancy']]
sortedLifeExp
# Out:
#                    Country  F_Life Expectancy  M_Life Expectancy
# 11  Hong Kong, China (SAR)               86.8               81.2
# 19                   Japan               86.7               80.2
# 10               Singapore               86.0               79.9
# 26                   Italy               85.5               80.6
# 25                   Spain               85.3               79.8
# 21                  France               85.1               79.2
# 2              Switzerland               85.0               80.8
# 16     Korea (Republic of)               85.0               78.5
# 1                Australia               84.5               80.3
# 41                   Chile               84.5               78.6

# %%
plt.ylabel('Count')
plt.xlabel('Country')
plt.title('Life Expectancy at Birth')
plt.bar(sortedLifeExp['Country'], sortedLifeExp['F_Life Expectancy'], color='lightcoral', label='Female')
plt.bar(sortedLifeExp['Country'], sortedLifeExp['M_Life Expectancy'], color='darkslategrey', label='Male')
plt.xticks(rotation=90)

plt.legend(loc='upper left')
plt.savefig('Life Exp Top 10.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
sortedExpEduc = genderDev_DF.sort_values(by=['F_Exp Education Years', 'M_Exp Education Years'], ascending=False).head(10)
sortedExpEduc = sortedExpEduc[['Country', 'F_Exp Education Years', 'M_Exp Education Years', 
                                 'F_Mean Educ Years', 'M_Mean Educ Years']]
sortedExpEduc
# Out:
#         Country  F_Exp Education Years  M_Exp Education Years  \
# 1     Australia                   20.7                   19.7
# 15      Iceland                   20.1                   17.9
# 9   New Zealand                   20.0                   18.3
# 3       Denmark                   19.3                   18.1
# 39    Argentina                   19.1                   16.8
# 6       Ireland                   18.5                   18.7
# 0        Norway                   18.2                   16.8
# 4   Netherlands                   18.0                   17.9
# 28       Greece                   17.7                   17.6
# 25        Spain                   17.7                   17.0
#
#     F_Mean Educ Years  M_Mean Educ Years
# 1                13.1               12.9
# 15               10.8               10.4
# 9                12.5               12.6
# 3                12.8               12.7
# 39                9.8                9.8
# ...

# %%
plt.ylabel('Count')
plt.xlabel('Country')
plt.title('Expected Years of Education')
plt.bar(sortedExpEduc['Country'], sortedExpEduc['F_Exp Education Years'], color='lightcoral', label='Female')
plt.bar(sortedExpEduc['Country'], sortedExpEduc['M_Exp Education Years'], color='darkslategrey', label='Male')
sns.lineplot(sortedExpEduc['Country'], sortedExpEduc['F_Mean Educ Years'], color='lightsalmon')
sns.lineplot(sortedExpEduc['Country'], sortedExpEduc['M_Mean Educ Years'], color='aquamarine')
plt.xticks(rotation=90)

plt.legend(loc='upper left')
plt.savefig('Exp Educ Years Top 10.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sortedGNI = genderDev_DF.sort_values(by=['F_Est GNI', 'M_Est GNI'], ascending=False).head(10)
sortedGNI = sortedGNI[['Country', 'F_Est GNI', 'M_Est GNI']]
sortedGNI
# Out:
#                    Country  F_Est GNI  M_Est GNI
# 10               Singapore      59994      93699
# 0                   Norway      57140      72825
# 32                   Qatar      55123     143979
# 30       Brunei Darussalam      54228      90437
# 18              Luxembourg      47723      69800
# 2              Switzerland      44132      69077
# 7            United States      43054      63158
# 47                  Kuwait      42292     111988
# 13                  Sweden      40222      51084
# 11  Hong Kong, China (SAR)      38060      72052

# %%
plt.ylabel('GNI')
plt.xlabel('Country')
plt.title('Estimated GNI')
plt.xticks(rotation=90)

plt.bar(sortedGNI['Country'], sortedGNI['M_Est GNI'], color='darkslategrey', label='Male')
plt.bar(sortedGNI['Country'], sortedGNI['F_Est GNI'], color='lightcoral', label='Female')

plt.legend()
plt.savefig('Est GNI Top 10.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ### Gender Inequality

# %%
sortedGII = genderIneq_DF.sort_values(by=['GII'], ascending=False).head(10)
sortedGII = sortedGII[['Country', 'GII']]
sortedGII
# Out:
#                                 Country    GII
# 159                               Yemen  0.744
# 187                               Niger  0.713
# 184                                Chad  0.706
# 170                         Afghanistan  0.693
# 171                       Côte d'Ivoire  0.679
# 178                                Mali  0.677
# 175  Congo (Democratic Republic of the)  0.673
# 99                                Tonga  0.666
# 186            Central African Republic  0.655
# 176                             Liberia  0.651

# %%
plt.title('Gender Inequality Index of Each Country')
sns.lineplot(sortedGII['Country'], sortedGII['GII'], color='peru')
plt.xticks(rotation=90)

plt.savefig('GII Top 10.png', dpi=300, bbox_inches='tight')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sortedMMR = genderIneq_DF.sort_values(by=['MMR'], ascending=False).head(10)
sortedMMR = sortedMMR[['Country', 'MMR']]
sortedMMR
# Out:
#                                 Country   MMR
# 180                        Sierra Leone  1100
# 184                                Chad   980
# 186            Central African Republic   880
# 183                             Burundi   740
# 168                         South Sudan   730
# 175  Congo (Democratic Republic of the)   730
# 171                       Côte d'Ivoire   720
# 181                              Guinea   650
# 176                             Liberia   640
# 187                               Niger   630

# %%
plt.title('Maternal Mortality Ratio of Each Country')
sns.lineplot(sortedMMR['Country'], sortedMMR['MMR'], color='peru')
plt.xticks(rotation=90)

plt.savefig('MMR Top 10.png', dpi=300, bbox_inches='tight')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sortedABR = genderIneq_DF.sort_values(by=['ABR'], ascending=False).head(10)
sortedABR = sortedABR[['Country', 'ABR']]
sortedABR
# Out:
#                                 Country    ABR
# 187                               Niger  204.8
# 178                                Mali  175.6
# 148                              Angola  170.2
# 184                                Chad  152.0
# 172                              Malawi  144.8
# 179                          Mozambique  137.8
# 175  Congo (Democratic Republic of the)  135.3
# 181                              Guinea  131.0
# 171                       Côte d'Ivoire  130.3
# 135                               Congo  126.7

# %%
plt.title('Adolescent Birth Rate of Each Country')
sns.lineplot(sortedABR['Country'], sortedABR['ABR'], color='peru')
plt.xticks(rotation=90)

plt.savefig('ABR Top 10.png', dpi=300, bbox_inches='tight')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sortedPRP = genderIneq_DF.sort_values(by=['PRP'], ascending=False).head(10)
sortedPRP = sortedPRP[['Country', 'PRP']]
sortedPRP
# Out:
#                               Country   PRP
# 163                            Rwanda  57.5
# 118  Bolivia (Plurinational State of)  51.8
# 33                            Andorra  50.0
# 66                               Cuba  48.9
# 63                         Seychelles  43.8
# 13                             Sweden  43.6
# 169                           Senegal  42.7
# 23                            Finland  42.5
# 20                            Belgium  42.4
# 87                            Ecuador  41.6

# %%
plt.title('Percent Representation in Parliament')
sns.lineplot(sortedPRP['Country'], sortedPRP['PRP'], color='peru')
plt.xticks(rotation=90)

plt.savefig('PRP Top 10.png', dpi=300, bbox_inches='tight')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sortedPopHS = genderIneq_DF.sort_values(by=['F_PopHS', 'M_PopHS'], ascending=False).head(10)
sortedPopHS = sortedPopHS[['Country', 'F_PopHS', 'M_PopHS']]
sortedPopHS
# Out:
#            Country  F_PopHS  M_PopHS
# 8           Canada    100.0    100.0
# 18      Luxembourg    100.0    100.0
# 22         Austria    100.0    100.0
# 23         Finland    100.0    100.0
# 29         Estonia    100.0    100.0
# 27  Czech Republic     99.9     99.7
# 14  United Kingdom     99.8     99.9
# 34        Slovakia     99.1     99.5
# 45          Latvia     98.9     99.0
# 43         Hungary     97.9     98.7

# %%
plt.ylabel('Count')
plt.xlabel('Country')
plt.title('Population with Secondary Education')
sns.lineplot(sortedPopHS['Country'], sortedPopHS['F_PopHS'], color='lightcoral', label='Female')
sns.lineplot(sortedPopHS['Country'], sortedPopHS['M_PopHS'], color='darkslategrey', label='Male')
plt.xticks(rotation=90)

plt.legend(loc='lower left')
plt.savefig('PopHS Top 10.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sortedLabor = genderIneq_DF.sort_values(by=['F_Labor Force', 'M_Labor Force'], ascending=False).head(10)
sortedLabor = sortedLabor[['Country', 'F_Labor Force', 'M_Labor Force']]
sortedLabor
# Out:
#                            Country  F_Labor Force  M_Labor Force
# 150  Tanzania (United Republic of)           88.1           90.2
# 153                     Madagascar           86.6           90.5
# 163                         Rwanda           86.4           85.3
# 179                     Mozambique           85.5           82.8
# 172                         Malawi           84.6           81.5
# 183                        Burundi           83.3           82.0
# 154                       Zimbabwe           83.2           89.7
# 137              Equatorial Guinea           80.7           92.2
# 161                           Togo           80.6           81.3
# 185                        Eritrea           80.0           89.8

# %%
plt.ylabel('Count')
plt.xlabel('Country')
plt.title('Labor Force Participation')
sns.lineplot(sortedLabor['Country'], sortedLabor['F_Labor Force'], color='pink', label='Female')
sns.lineplot(sortedLabor['Country'], sortedLabor['M_Labor Force'], color='blue', label='Male')
plt.xticks(rotation=90)

plt.legend(loc='upper left')
plt.show()
plt.savefig('Labor Force Top 10.png', dpi=300)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## Historical Index

# %%
sorted2HDI = histIndex_DF.sort_values(by=['HDI(1990)', 'HDI(2000)', 'HDI(2010)', 
                                           'HDI(2011)', 'HDI(2012)', 'HDI(2013)', 
                                           'HDI(2014)'], ascending=False).head(10)
sorted2HDI = sorted2HDI[['Country', 'HDI(1990)', 'HDI(2000)', 'HDI(2010)', 
                                           'HDI(2011)', 'HDI(2012)', 'HDI(2013)', 
                                           'HDI(2014)']]
sorted2HDI
# Out:
#           Country  HDI(1990)  HDI(2000)  HDI(2010)  HDI(2011)  HDI(2012)  \
# 1       Australia      0.865      0.898      0.927      0.930      0.932
# 7   United States      0.859      0.883      0.909      0.911      0.912
# 0          Norway      0.849      0.917      0.940      0.941      0.942
# 8          Canada      0.849      0.867      0.903      0.909      0.910
# 2     Switzerland      0.831      0.888      0.924      0.925      0.927
# 4     Netherlands      0.829      0.877      0.909      0.919      0.920
# 9     New Zealand      0.820      0.874      0.905      0.907      0.909
# 13         Sweden      0.815      0.897      0.901      0.903      0.904
# 19          Japan      0.814      0.857      0.884      0.886      0.888
# 20        Belgium      0.806      0.874      0.883      0.886      0.889
#
#     HDI(2013)  HDI(2014)
# 1       0.933      0.935
# 7       0.913      0.915
# 0       0.942      0.944
# 8       0.912      0.913
# 2       0.928      0.930
# ...

# %%
plt.title('Human Development Index')
sns.lineplot(sorted2HDI['Country'], sorted2HDI['HDI(1990)'], color='green', label='1990')
sns.lineplot(sorted2HDI['Country'], sorted2HDI['HDI(2000)'], color='blue', label='2000')
sns.lineplot(sorted2HDI['Country'], sorted2HDI['HDI(2010)'], color='red', label='2010')
sns.lineplot(sorted2HDI['Country'], sorted2HDI['HDI(2011)'], color='yellow', label='2011')
sns.lineplot(sorted2HDI['Country'], sorted2HDI['HDI(2012)'], color='cyan', label='2012')
sns.lineplot(sorted2HDI['Country'], sorted2HDI['HDI(2013)'], color='orange', label='2013')
sns.lineplot(sorted2HDI['Country'], sorted2HDI['HDI(2014)'], color='pink', label='2014')
plt.xticks(rotation=90)

plt.savefig('HDI.png', dpi=300)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %% [markdown]
# ## Human Development Index (HDI)

# %% [markdown]
# ### Human Development

# %%
sorted3HDI = humanDev_DF.sort_values(by=['HDI'], ascending=False).head(10)
sorted3HDI = sorted3HDI[['Country', 'HDI']]
sorted3HDI
# Out:
#          Country    HDI
# 0         Norway  0.944
# 1      Australia  0.935
# 2    Switzerland  0.930
# 3        Denmark  0.923
# 4    Netherlands  0.922
# 5        Germany  0.916
# 6        Ireland  0.916
# 7  United States  0.915
# 8         Canada  0.913
# 9    New Zealand  0.913

# %%
plt.title('Human Development Index')
plt.xlabel('Country')
plt.ylabel('Count')
sns.lineplot(sorted3HDI['Country'], sorted3HDI['HDI'], color='darkgreen')
plt.xticks(rotation=90)

plt.savefig('HDI3.png', dpi=300, bbox_inches='tight')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sortedLifeExp = humanDev_DF.sort_values(by=['Life Expectancy'], ascending=False).head(10)
sortedLifeExp = sortedLifeExp[['Country', 'Life Expectancy']]
sortedLifeExp
# Out:
#                    Country  Life Expectancy
# 11  Hong Kong, China (SAR)             84.0
# 19                   Japan             83.5
# 26                   Italy             83.1
# 2              Switzerland             83.0
# 10               Singapore             83.0
# 25                   Spain             82.6
# 15                 Iceland             82.6
# 1                Australia             82.4
# 17                  Israel             82.4
# 21                  France             82.2

# %%
fig = plt.figure(figsize=(9,5))
plt.title('Life Expectancy at Birth')
sns.lineplot(sortedLifeExp['Country'], sortedLifeExp['Life Expectancy'], color='green')
plt.xticks(rotation=90)


plt.savefig('LifeExp.png', dpi=300, bbox_inches='tight')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sortedExpEduc = humanDev_DF.sort_values(by=['Exp Educ Years', 'Mean Educ Years'], ascending=False).head(10)
sortedExpEduc = sortedExpEduc[['Country', 'Exp Educ Years', 'Mean Educ Years']]
sortedExpEduc
# Out:
#         Country  Exp Educ Years  Mean Educ Years
# 1     Australia            20.2             13.0
# 9   New Zealand            19.2             12.5
# 15      Iceland            19.0             10.6
# 3       Denmark            18.7             12.7
# 6       Ireland            18.6             12.2
# 4   Netherlands            17.9             11.9
# 39    Argentina            17.9              9.8
# 28       Greece            17.6             10.3
# 0        Norway            17.5             12.6
# 25        Spain            17.3              9.6

# %%
plt.title('Expected Education Years')
# fig = plt.figure(figsize=(9,5))

plt.bar(sortedExpEduc['Country'], sortedExpEduc['Exp Educ Years'], color='darkseagreen', label='Education Years')
sns.lineplot(sortedExpEduc['Country'], sortedExpEduc['Mean Educ Years'], color='cyan', label='Mean')
plt.xticks(rotation=90)
plt.ylabel('Education Years')

plt.savefig('ExpEducYears.png', dpi=300, bbox_inches='tight')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sortedGNICap = humanDev_DF.sort_values(by=['GNI'], ascending=False).head(10)
sortedGNICap = sortedGNICap[['Country', 'GNI']]
sortedGNICap
# Out:
#                    Country       GNI
# 32                   Qatar  123124.0
# 47                  Kuwait   83961.0
# 12           Liechtenstein   79851.0
# 10               Singapore   76628.0
# 30       Brunei Darussalam   72570.0
# 0                   Norway   64992.0
# 40    United Arab Emirates   60868.0
# 18              Luxembourg   58711.0
# 2              Switzerland   56431.0
# 11  Hong Kong, China (SAR)   53959.0

# %%
plt.title('Gross National Income (GNI) per Capita')
sns.lineplot(sortedGNICap['Country'], sortedGNICap['GNI'], color='green')
plt.xticks(rotation=90)

plt.savefig('GNICap.png', dpi=300, bbox_inches='tight')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sortedGNI_HDI = humanDev_DF.sort_values(by=['GNI_R-HDI_R'], ascending=False).head(10)
sortedGNI_HDI = sortedGNI_HDI[['Country', 'GNI_R-HDI_R']]
sortedGNI_HDI
# Out:
#         Country  GNI_R-HDI_R
# 66         Cuba         47.0
# 75      Georgia         40.0
# 99        Tonga         32.0
# 72    Sri Lanka         29.0
# 119  Kyrgyzstan         29.0
# 48   Montenegro         27.0
# 128  Tajikistan         27.0
# 56     Barbados         27.0
# 81      Ukraine         25.0
# 104       Samoa         24.0

# %%
plt.title('GNI per Capita Rank minus HDI Rank')
sns.lineplot(sortedGNI_HDI['Country'], sortedGNI_HDI['GNI_R-HDI_R'], color='green')
plt.xticks(rotation=90)
plt.ylabel('Counts')

plt.savefig('GNIHDI.png', dpi=300)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### Inequality Adjusted

# %%
sortedHDI_IHDI = ineqAdj_DF.sort_values(by=['HDI', 'IHDI'], ascending=False).head(10)
sortedHDI_IHDI = sortedHDI_IHDI[['Country', 'HDI', 'IHDI']]
sortedHDI_IHDI
# Out:
#          Country    HDI   IHDI
# 0         Norway  0.944  0.893
# 1      Australia  0.935  0.858
# 2    Switzerland  0.930  0.861
# 3        Denmark  0.923  0.856
# 4    Netherlands  0.922  0.861
# 5        Germany  0.916  0.853
# 6        Ireland  0.916  0.836
# 7  United States  0.915  0.760
# 8         Canada  0.913  0.832
# 9    New Zealand  0.913  0.000

# %%
plt.xticks(rotation=90)
plt.ylabel('Count')
plt.title('Human Development Index')
sns.lineplot(sortedHDI_IHDI['Country'], sortedHDI_IHDI['HDI'], color='green', label='HDI')
sns.lineplot(sortedHDI_IHDI['Country'], sortedHDI_IHDI['IHDI'], color='blue', label='IHDI')


plt.savefig('HDI_IHDI.png', dpi=300)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sortedIHDILossDiff = ineqAdj_DF.sort_values(by=['IHDI Loss', 'IHDI Diff'], ascending=False).head(10)
sortedIHDILossDiff = sortedIHDILossDiff[['Country', 'IHDI Loss', 'IHDI Diff']]
sortedIHDILossDiff
# Out:
#                       Country  IHDI Loss  IHDI Diff
# 158                   Comoros       46.7        -18
# 126                   Namibia       43.6        -25
# 186  Central African Republic       43.5         -1
# 180              Sierra Leone       41.7         -4
# 184                      Chad       39.9         -1
# 177             Guinea-Bissau       39.6         -5
# 162                     Haiti       38.8         -7
# 105                  Botswana       38.2        -23
# 171             Côte d'Ivoire       38.0         -1
# 151                   Nigeria       37.8         -9

# %%
plt.xticks(rotation=90)
plt.ylabel('Count')
plt.title('Human Development Index')
sns.lineplot(sortedIHDILossDiff['Country'], sortedIHDILossDiff['IHDI Loss'], color='green', label='HDI')
sns.lineplot(sortedIHDILossDiff['Country'], sortedIHDILossDiff['IHDI Diff'], color='blue', label='IHDI')

plt.savefig('IHDILossDiff.png', dpi=300)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sortedCoeff = ineqAdj_DF.sort_values(by=['Coeff Human Ineq'], ascending=False).head(10)
sortedCoeff = sortedCoeff[['Country', 'Coeff Human Ineq']]
sortedCoeff
# Out:
#                       Country  Coeff Human Ineq
# 158                   Comoros              46.0
# 186  Central African Republic              43.1
# 180              Sierra Leone              40.0
# 184                      Chad              39.6
# 177             Guinea-Bissau              39.4
# 126                   Namibia              39.3
# 162                     Haiti              38.2
# 171             Côte d'Ivoire              37.6
# 151                   Nigeria              37.5
# 165                     Benin              37.1

# %%
plt.xticks(rotation=90)
plt.ylabel('Count')
plt.xlabel('Country')
plt.title('Coefficient of Human Inequality')
plt.bar(sortedCoeff['Country'], sortedCoeff['Coeff Human Ineq'], color='green')

plt.savefig('CoeffHuman.png', dpi=300)

# %%
sortedIneqLifeExp = ineqAdj_DF.sort_values(by=['Ineq Life Exp', 'IHDI Life Exp'], ascending=False).head(10)
sortedIneqLifeExp = sortedIneqLifeExp[['Country', 'Ineq Life Exp', 'IHDI Life Exp']]
sortedIneqLifeExp
# Out:
#                                 Country  Ineq Life Exp  IHDI Life Exp
# 180                        Sierra Leone           51.2          0.232
# 175  Congo (Democratic Republic of the)           49.9          0.298
# 148                              Angola           46.2          0.267
# 184                                Chad           46.1          0.262
# 186            Central African Republic           45.7          0.256
# 178                                Mali           45.6          0.318
# 177                       Guinea-Bissau           45.3          0.296
# 137                   Equatorial Guinea           44.4          0.322
# 183                             Burundi           43.6          0.318
# 182                        Burkina Faso           41.1          0.351

# %%
plt.xticks(rotation=90)
plt.ylabel('Count')
plt.xlabel('Country')
plt.title('Inequality Life Expectancy')
plt.bar(sortedIneqLifeExp['Country'], sortedIneqLifeExp['Ineq Life Exp'], color='green')


plt.savefig('IneqLifeExp.png', dpi=300)

# %%
plt.xticks(rotation=90)
plt.ylabel('Count')
plt.xlabel('Country')
plt.title('Inequality Adjusted Life Expectancy Index')
sns.lineplot(sortedIneqLifeExp['Country'], sortedIneqLifeExp['IHDI Life Exp'], color='green')

plt.savefig('IneqLifeAdj.png', dpi=300)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sortedIneqEduc = ineqAdj_DF.sort_values(by=['Education Ineq', 'Education IHDI'], ascending=False).head(10)
sortedIneqEduc = sortedIneqEduc[['Country', 'Education Ineq', 'Education IHDI']]
sortedIneqEduc
# Out:
#            Country  Education Ineq  Education IHDI
# 180   Sierra Leone            49.6           0.171
# 181         Guinea            48.3           0.167
# 159          Yemen            48.1           0.177
# 158        Comoros            47.6           0.248
# 132    Timor-Leste            47.6           0.247
# 167       Djibouti            47.0           0.162
# 176        Liberia            46.4           0.215
# 125        Morocco            45.8           0.253
# 171  Côte d'Ivoire            45.1           0.214
# 131         Bhutan            44.8           0.249

# %%
plt.xticks(rotation=90)
plt.ylabel('Count')
plt.xlabel('Country')
plt.title('Inequality in Education')
sns.lineplot(sortedIneqEduc['Country'], sortedIneqEduc['Education Ineq'], color='green')

plt.savefig('EducIneq.png', dpi=300)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.xticks(rotation=90)
plt.ylabel('Count')
plt.xlabel('Country')
plt.title('Inequality Adjusted Education Index')
sns.lineplot(sortedIneqEduc['Country'], sortedIneqEduc['Education IHDI'], color='green')

plt.savefig('EducIneqAdj.png', dpi=300)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sortedIneqIncome = ineqAdj_DF.sort_values(by=['Income Ineq', 'Income IHDI'], ascending=False).head(10)
sortedIneqIncome = sortedIneqIncome[['Country', 'Income Ineq', 'Income IHDI']]
sortedIneqIncome
# Out:
#                         Country  Income Ineq  Income IHDI
# 126                     Namibia         68.3        0.217
# 116                South Africa         57.3        0.310
# 158                     Comoros         56.0        0.178
# 105                    Botswana         55.5        0.344
# 186    Central African Republic         49.2        0.135
# 130                    Honduras         48.6        0.285
# 136                    Kiribati         48.4        0.249
# 162                       Haiti         48.4        0.219
# 160                     Lesotho         47.0        0.280
# 69   Iran (Islamic Republic of)         46.6        0.407

# %%
plt.xticks(rotation=90)
plt.ylabel('Count')
plt.xlabel('Country')
plt.title('Inequality in Income')
sns.lineplot(sortedIneqIncome['Country'], sortedIneqIncome['Income Ineq'], color='green')

plt.savefig('IncomeIneq.png', dpi=300)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.xticks(rotation=90)
plt.ylabel('Count')
plt.xlabel('Country')
plt.title('Inequality-Adjusted Income Index')
sns.lineplot(sortedIneqIncome['Country'], sortedIneqIncome['Income IHDI'], color='green')

plt.savefig('IncomeIneqAdj.png', dpi=300)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sortedInIncome = ineqAdj_DF.sort_values(by=['Income Ineq(Quantile)', 'Income Ineq(Palma)',
                                            'Income Ineq(Gini)'], ascending=False).head(10)
sortedInIncome = sortedInIncome[['Country', 'Income Ineq(Quantile)', 'Income Ineq(Palma)', 'Income Ineq(Gini)']]
sortedInIncome
# Out:
#                               Country  Income Ineq(Quantile)  \
# 122  Micronesia (Federated States of)                   40.2
# 116                      South Africa                   28.5
# 158                           Comoros                   26.7
# 162                             Haiti                   26.6
# 130                          Honduras                   23.5
# 105                          Botswana                   22.9
# 160                           Lesotho                   20.4
# 126                           Namibia                   19.6
# 63                         Seychelles                   18.8
# 186          Central African Republic                   18.0
#
#      Income Ineq(Palma)  Income Ineq(Gini)
# 122                 7.0               61.1
# 116                 8.0               65.0
# 158                 7.0               64.3
# 162                 5.5               59.2
# 130                 5.0               57.4
# ...

# %%
plt.xticks(rotation=90)
plt.ylabel('Count')
plt.xlabel('Country')
plt.title('Income Inequality')
sns.lineplot(sortedInIncome['Country'], sortedInIncome['Income Ineq(Quantile)'], color='green', label='Quantile')
sns.lineplot(sortedInIncome['Country'], sortedInIncome['Income Ineq(Palma)'], color='Red', label='Palma Ratio')
sns.lineplot(sortedInIncome['Country'], sortedInIncome['Income Ineq(Gini)'], color='blue', label='Gini Coefficient')

plt.savefig('IncomeIneq1.png', dpi=300)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## Multidimensional Poverty

# %%
sortedMPI = multiPoverty_DF.sort_values(by=['MPI', 'MPI HDRO'], ascending=False).head(10)
sortedMPI = sortedMPI[['Country', 'MPI', 'MPI HDRO']]
sortedMPI
# Out:
#           Country    MPI  MPI HDRO
# 66          Niger  0.584      89.8
# 80    South Sudan  0.551      89.3
# 19           Chad  0.545      86.9
# 30       Ethiopia  0.537      88.2
# 14   Burkina Faso  0.508      82.8
# 78        Somalia  0.500      81.8
# 36  Guinea-Bissau  0.495      80.4
# 55           Mali  0.456      78.4
# 15        Burundi  0.442      81.8
# 35         Guinea  0.425      73.8

# %%
plt.xticks(rotation=90)
plt.ylabel('Count')
plt.title('Multidimensional Poverty Index')
sns.lineplot(sortedMPI['Country'], sortedMPI['MPI'], color='peru')

plt.savefig('MPI.png', dpi=300, bbox_inches='tight')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.xticks(rotation=90)
plt.ylabel('Count')
plt.title('Multidimensional Poverty Index Percent')
sns.lineplot(sortedMPI['Country'], sortedMPI['MPI HDRO'], color='peru')

plt.savefig('MPI HDRO.png', dpi=300)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sortedMPI2010 = multiPoverty_DF.sort_values(by=['MPI(2010)', 'MPI(2010) Percent'], ascending=False).head(10)
sortedMPI2010 = sortedMPI2010[['Country', 'MPI(2010)', 'MPI(2010) Percent']]
sortedMPI2010
# Out:
#           Country  MPI(2010)  MPI(2010) Percent
# 66          Niger      0.605               89.3
# 30       Ethiopia      0.564               87.3
# 80    South Sudan      0.557               91.1
# 19           Chad      0.554               87.2
# 14   Burkina Faso      0.535               84.0
# 78        Somalia      0.514               81.2
# 77   Sierra Leone      0.464               81.0
# 36  Guinea-Bissau      0.462               77.5
# 35         Guinea      0.459               75.1
# 55           Mali      0.457               77.7

# %%
plt.xticks(rotation=90)
plt.ylabel('Count')
plt.title('Multidimensional Poverty Index (2010)')
sns.lineplot(sortedMPI2010['Country'], sortedMPI2010['MPI(2010)'], color='peru')

plt.savefig('MPI2010.png', dpi=300)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.xticks(rotation=90)
plt.ylabel('Count')
plt.title('Multidimensional Poverty Index Percent (2010)')
sns.lineplot(sortedMPI2010['Country'], sortedMPI2010['MPI(2010) Percent'], color='peru')

plt.savefig('MPIPercent2010.png', dpi=300)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sortedmultiPov = multiPoverty_DF.sort_values(by=['Population Multi Poverty'], ascending=False).head(10)
sortedmultiPov = sortedmultiPov[['Country', 'Population Multi Poverty']]
sortedmultiPov
# Out:
#                                Country  Population Multi Poverty
# 40                               India                  631999.0
# 67                             Nigeria                   88425.0
# 68                            Pakistan                   83045.0
# 30                            Ethiopia                   78887.0
# 5                           Bangladesh                   75610.0
# 20                               China                   71939.0
# 24  Congo (Democratic Republic of the)                   50312.0
# 86       Tanzania (United Republic of)                   29842.0
# 93                              Uganda                   24712.0
# 46                               Kenya                   19190.0

# %%
plt.xticks(rotation=90)
plt.ylabel('Count')
plt.xlabel('Country')
plt.title('Population Multiidimensional Poverty')
plt.bar(sortedmultiPov['Country'], sortedmultiPov['Population Multi Poverty'], color='darkseagreen', label='Population')

plt.savefig('multiPov.png', dpi=300)

# %%
sortedDeprivation = multiPoverty_DF.sort_values(by=['Deprivation Intensity', 'Educational Deprivation', 
                                                  'Health Deprivation', 'Living Standards'], ascending=False).head(10)
sortedDeprivation = sortedDeprivation[['Country', 'Deprivation Intensity', 'Educational Deprivation', 
                                                  'Health Deprivation', 'Living Standards']]
sortedDeprivation
# Out:
#           Country  Deprivation Intensity  Educational Deprivation  \
# 66          Niger                   65.0                     35.9
# 19           Chad                   62.7                     32.3
# 80    South Sudan                   61.7                     39.3
# 36  Guinea-Bissau                   61.6                     30.5
# 14   Burkina Faso                   61.3                     39.0
# 78        Somalia                   61.1                     33.7
# 30       Ethiopia                   60.9                     27.4
# 55           Mali                   58.2                     37.9
# 35         Guinea                   57.6                     36.6
# 62     Mozambique                   55.6                     30.4
#
#     Health Deprivation  Living Standards
# 66                24.0              40.0
# 19                22.5              45.2
# 80                14.3              46.3
# 36                27.9              41.6
# ...

# %%
plt.xticks(rotation=90)
plt.ylabel('Count')
plt.xlabel('Country')
plt.title('Deprivation Intensity')
plt.bar(sortedDeprivation['Country'], sortedDeprivation['Deprivation Intensity'], color='navajowhite', label='Deprivation Intensity')
sns.lineplot(sortedDeprivation['Country'], sortedDeprivation['Educational Deprivation'], color='darkseagreen', label='Educational Deprivation')
sns.lineplot(sortedDeprivation['Country'], sortedDeprivation['Health Deprivation'], color='saddlebrown', label='Health Deprivation')
sns.lineplot(sortedDeprivation['Country'], sortedDeprivation['Living Standards'], color='darkslateblue', label='Living Standards')

plt.legend(loc='lower right')
plt.savefig('deprivation.png', dpi=300, bbox_inches='tight')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sortedPovLine = multiPoverty_DF.sort_values(by=['Population Below Pov Line', 'Population Below 1.25'], ascending=False).head(10)
sortedPovLine = sortedPovLine[['Country', 'Population Below Pov Line', 'Population Below 1.25']]
sortedPovLine
# Out:
#                                 Country  Population Below Pov Line  \
# 52                           Madagascar                       75.3
# 100                            Zimbabwe                       72.3
# 36                        Guinea-Bissau                       69.3
# 15                              Burundi                       66.9
# 39                             Honduras                       64.5
# 50                              Liberia                       63.8
# 24   Congo (Democratic Republic of the)                       63.6
# 83                            Swaziland                       63.0
# 18             Central African Republic                       62.0
# 74                Sao Tome and Principe                       61.7
#
#      Population Below 1.25
# 52                    87.7
# 100                    0.0
# 36                    48.9
# 15                    81.3
# 39                    16.5
# 50                    83.8
# 24                    87.7
# ...

# %%
plt.xticks(rotation=90)
plt.ylabel('Count')
plt.xlabel('Country')
plt.title('Population Poverty Line')
sns.lineplot(sortedPovLine['Country'], sortedPovLine['Population Below Pov Line'], color='lightcoral', label='Below the Poverty Line')
sns.lineplot(sortedPovLine['Country'], sortedPovLine['Population Below 1.25'], color='darkslategrey', label='Below $1.25 per Day')

plt.savefig('PovLine.png', dpi=300)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
